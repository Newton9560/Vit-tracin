# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import sys
sys.path.append("..")
import utils

# %%
x_train = []
y_train = []
x_val = []
y_val = []
for index in range(5):
    x_i_train, y_i_train = utils.readcsv("./train_acc_" + str(index + 1) + "0.csv")
    x_i_val, y_i_val = utils.readcsv("./val_acc_" + str(index + 1) + "0.csv")
    x_train.append(x_i_train)
    y_train.append(y_i_train)
    x_val.append(x_i_val)
    y_val.append(y_i_val)
x_i_train, y_i_train = utils.readcsv("./run-train_acc.csv")
x_i_val, y_i_val = utils.readcsv("./run-val_acc.csv")
x_train.append(x_i_train)
y_train.append(y_i_train)
x_val.append(x_i_val)
y_val.append(y_i_val)

# %%
utils.show_lines(x_train, y_train)

# %%
utils.show_lines(x_val, y_val)
